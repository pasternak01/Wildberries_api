# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from setuptools.command.rotate import rotate
from streamlit import plotly_chart

df = pd.read_excel("Docs/4 остатки склада wb.XLSX", header=1)

# %%
df.head(5)
new_columns_names = ['brand', 'item_type', 'season', 'collection', 'name', 'saler_article', 'wp_article', 'barcode', 'size', 'contract', 'warehouse', 'ordered_qty', 'summ_without_wb_commission', 'bought_qty', 'payments', 'remain_qty']

len(new_columns_names), len(df.columns)
columns_dict = {}
for i, v in zip(df.columns, new_columns_names):
    columns_dict[v] = i
    print(f"{v} - {i}")


df.columns = new_columns_names
df.head(5)
# Out:
# brand - Бренд
# item_type - Предмет
# season - Сезон
# collection - Коллекция
# name - Наименование
# saler_article - Артикул продавца
# wp_article - Артикул WB
# barcode - Баркод
# size - Размер
# contract - Контракт
# warehouse - Склад
# ordered_qty - шт.
# summ_without_wb_commission - Сумма заказов минус комиссия WB, руб.
# bought_qty - Выкупили, шт.
# payments - К перечислению за товар, руб.
# remain_qty - Текущий остаток, шт.
#            brand       item_type season  collection  \
# 0  INSEENSE GOLD  Ватные палочки    NaN         NaN
# 1  INSEENSE GOLD  Ватные палочки    NaN         NaN
# 2  INSEENSE GOLD  Ватные палочки    NaN         NaN
# 3  INSEENSE GOLD  Ватные палочки    NaN         NaN
# 4  INSEENSE GOLD  Ватные палочки    NaN         NaN
#
#                                              name saler_article  wp_article  \
# 0  Детские ватные палочки с ограничителями 50 шт.       Ins50pa     8348552
# 1  Детские ватные палочки с ограничителями 50 шт.       Ins50pa     8348552
# 2  Детские ватные палочки с ограничителями 50 шт.       Ins50pa     8348552
# 3  Детские ватные палочки с ограничителями 50 шт.       Ins50pa     8348552
# 4  Детские ватные палочки с ограничителями 50 шт.       Ins50pa     8348552
#
#          barcode size contract     warehouse  ordered_qty  \
# 0  4650099650400    0      NaN  Белые Столбы            1
# 1  4650099650400    0      NaN  Электросталь            1
# 2  4650099650400    0      NaN   Новосибирск            1
# 3  4650099650400    0      NaN      Коледино            1
# 4  4650099650400    0      NaN        Казань          138
#
#    summ_without_wb_commission  bought_qty  payments  remain_qty
# 0                      144.15           1    144.15           0
# 1                      144.15           0      0.00           0
# 2                      162.75           1    162.75           0
# 3                      144.15           1    162.75           0
# 4                    21369.07         139  21700.22          34

# %%
shape = df.shape
print(f"строк: {shape[0]}, столбцов: {shape[1]}")
df.isnull().sum()
# Out:
# строк: 658, столбцов: 16
# brand                           0
# item_type                       0
# season                        657
# collection                    658
# name                            0
# saler_article                   0
# wp_article                      0
# barcode                         0
# size                            0
# contract                      647
# warehouse                       0
# ordered_qty                     0
# summ_without_wb_commission      0
# bought_qty                      0
# payments                        0
# remain_qty                      0
# dtype: int64

# %%
df = df.drop(columns=['collection', 'season', 'contract'])

# %%
df.dtypes
# Out:
# brand                          object
# item_type                      object
# name                           object
# saler_article                  object
# wp_article                      int64
# barcode                         int64
# size                           object
# warehouse                      object
# ordered_qty                     int64
# summ_without_wb_commission    float64
# bought_qty                      int64
# payments                      float64
# remain_qty                      int64
# dtype: object

# %%
df1 = df[['name','item_type','ordered_qty', 'bought_qty' ]].groupby('name').sum()

df1['bought_qty'] = df1.apply(lambda row: min(row['bought_qty'], row['ordered_qty']), axis=1)
df1['diff'] =( (df1['ordered_qty'] - df1['bought_qty']) / df1['ordered_qty'] *100).round(2)
df1.sort_values(by='diff', ascending=False)
# Out:
#                                                                                          item_type  \
# name
# Гель для стирки детский с рождения  2 л.                                           Гели для стирки
# Гель концентрат для стирки  1500 мл                                                Гели для стирки
# Прокладки послеродовые в роддом 350 мм              Прокладки гигиеническиеПрокладки гигиенические
# Пеленки одноразовые 60х90 впитывающие, 60 шт 2 ...                            Пеленки для животных
# Подгузники для детей М размер 3 6-11 кг 66 шт                 Подгузники детскиеПодгузники детские
# ...                                                                                            ...
# Пеленки детские одноразовые впитывающие 2 уп. п...                            Пеленки для животных
# Пеленки одноразовые 60х90, 15 штук                                            Пеленки для животных
# Подгузники-трусики ультратонкие V5S М 6-11 кг 3...                              Подгузники детские
# Прокладки вкладыши 20шт 110мм                                                  Прокладки для груди
# Трусы прокладки гигиенические послеродовые одно...                               Трусы одноразовые
#
#                                                     ordered_qty  bought_qty  \
# name
# Гель для стирки детский с рождения  2 л.                      1           0
# Гель концентрат для стирки  1500 мл                           1           0
# Прокладки послеродовые в роддом 350 мм                        3           0
# Пеленки одноразовые 60х90 впитывающие, 60 шт 2 ...            1           0
# Подгузники для детей М размер 3 6-11 кг 66 шт                 4           0
# ...                                                         ...         ...
# Пеленки детские одноразовые впитывающие 2 уп. п...            0           0
# Пеленки одноразовые 60х90, 15 штук                            0           0
# Подгузники-трусики ультратонкие V5S М 6-11 кг 3...            0           0
# Прокладки вкладыши 20шт 110мм                                 0           0
# Трусы прокладки гигиенические послеродовые одно...            0           0
#
#                                                      diff
# name
# Гель для стирки детский с рождения  2 л.            100.0
# Гель концентрат для стирки  1500 мл                 100.0
# Прокладки послеродовые в роддом 350 мм              100.0
# Пеленки одноразовые 60х90 впитывающие, 60 шт 2 ...  100.0
# Подгузники для детей М размер 3 6-11 кг 66 шт       100.0
# ...                                                   ...
# Пеленки детские одноразовые впитывающие 2 уп. п...    NaN
# Пеленки одноразовые 60х90, 15 штук                    NaN
# Подгузники-трусики ультратонкие V5S М 6-11 кг 3...    NaN
# Прокладки вкладыши 20шт 110мм                         NaN
# Трусы прокладки гигиенические послеродовые одно...    NaN
#
# [170 rows x 4 columns]

# %%
# Out:
#                                                     ordered_qty  bought_qty
# name
# Бумажные детские салфетки супермягкие 150 шт.+2...           46          42
# Бумажные салфетки детские супермягкие 2 уп. по ...           17          15
# Ватные диски  6 упаковок по 150 штук                         33          33
# Ватные диски овальные 240 шт 6 упаковок по 40 шт            234         234
# Ватные диски овальные 40 шт                                  15           4
# ...                                                         ...         ...
# Трусы фиксирующие для прокладки, 4 шт                        25          22
# Фитобальзам для детей и взрослых  30 мл                      10           8
# Чудо-крем защитный Inseense, 80мл                            18          18
# Шампунь-пенка детский для купания, 250 мл                    13           9
# таблетки для посудомоечной машины, 60 шт                     26          26
#
# [170 rows x 2 columns]

# %%
df.item_type.unique()
df1  = df.groupby('item_type')[['ordered_qty', 'bought_qty']].sum()

# %%
plt.figure(figsize=(22,6))
plt.title('Продажи по группам')
plt.bar(df1['ordered_qty'].index,  height=df1['ordered_qty'], width=1,  edgecolor='black')
plt.xticks(rotation=90, fontsize=20)
plt.axhline(df1['ordered_qty'].mean(), color='red')
plt.text(x = -1, y = df1['ordered_qty'].mean() + 50, s="Среднее", color='red', fontsize=20)

plt.show()

# %%
# df[['item_type', 'warehouse', 'ordered_qty', 'bought_qty']].groupby(['warehouse', 'item_type'])['ordered_qty'].sum()
df1 = df.groupby('warehouse')['ordered_qty'].sum().reset_index()
plt.bar(x=df1.warehouse, height=df1['ordered_qty'])
plt.xticks(rotation=90, fontsize=12)
plt.show()

# %%
df.warehouse.unique()
# Out:
# array(['Белые Столбы', 'Электросталь', 'Новосибирск', 'Коледино',
#        'Казань', 'Тула', 'Котовск', 'Склад поставщика - везу на склад WB',
#        'Екатеринбург - Испытателей 14г', 'Невинномысск',
#        'Астана Карагандинское шоссе', 'Краснодар',
#        'Санкт-Петербург Уткина Заводь', 'Подольск', 'Обухово 2',
#        'Остальные', 'Белая дача'], dtype=object)
